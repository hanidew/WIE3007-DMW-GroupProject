# %% [markdown]
# # SECTION 1A: Setup GitHub (ONE-TIME SETUP ONLY)
# **DO NOT RUN AGAIN AFTER FIRST TIME**
#
# You can comment this entire section after running it once

# %%
# ===============================
# ONE-TIME SETUP (RUN ONCE ONLY)
# ===============================

from google.colab import drive
drive.mount('/content/drive')

# Create project folder (if not exists)
# %cd /content/drive/MyDrive/
# !mkdir -p WIE3007_Project

# %cd /content/drive/MyDrive/WIE3007_Project

# ===============================
# STEP 1 — Generate SSH key (RUN ONCE)
# ===============================
# This creates your SSH key with no password (required for Colab)
# Accept overwrite = y if asked.
# !ssh-keygen -t ed25519 -C "youremail@gmail.com" -f ~/.ssh/id_ed25519 -N ""
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/WIE3007_Project
# Generating public/private ed25519 key pair.
# /root/.ssh/id_ed25519 already exists.
# Overwrite (y/n)? y
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:+jFUlBzWvLDkddId/IkSLnBlvyHSYSRnihOnFVyGqco hanijasmina@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |       ..*@/ ..o.|
# |       .*B#.B o..|
# |       ++=o*.*. o|
# |       ..o+oo.o..|
# |    . . S . ..   |
# |     E o         |
# |      . o        |
# |       . o       |
# |        .        |
# +----[SHA256]-----+
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAILiIvIYJTd+GmXwYsT7wDDYuIkyETzq1wsExmRE/L1iW hanijasmina@gmail.com
# Host key verification failed.
# Cloning into 'WIE3007-DMW-GroupProject'...
# ...

# %% [markdown]
# # ===============================
# ## STEP 2 — ADD KEY TO GITHUB
# # ===============================
#
# 1.   Go to GitHub
# 2.   Click your profile picture → Settings
# 3.   On the left menu → SSH and GPG Keys
# 4.   Click New SSH Key
# 5.   Title: Colab Key
# 6.   Key Type: Authentication Key
# 7.   Paste YOUR ENTIRE SSH key generated in Step 1; contoh: ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAILiIvIYJTd+GmXwYsT7wDDYuIkyETzq1wsExmRE/L1iW hanijasmina@gmail.com
# 8.   Save

# %%
# ===============================
# STEP 2 — Copy this key into GitHub
# ===============================
# !cat ~/.ssh/id_ed25519.pub

# ===============================
# STEP 3 — Fix File Permissions
# ===============================
# !chmod 700 ~/.ssh
# !chmod 600 ~/.ssh/id_ed25519

# ===============================
# STEP 4 — Add GitHub to known_hosts
# (Fix for "Host key verification failed")
# ===============================
# !ssh-keyscan github.com >> ~/.ssh/known_hosts
# !chmod 644 ~/.ssh/known_hosts

# ===============================
# STEP 5 — Test SSH connection
# ===============================
# Expected Output:
#   "Hi <username>! You've successfully authenticated..."
# !ssh -T git@github.com

# %%
# ===============================
# STEP 6 — Clone your repo using SSH (RUN ONCE ONLY)
# ===============================
# %cd /content/drive/MyDrive/WIE3007_Project
# !git clone git@github.com:hanidew/WIE3007-DMW-GroupProject.git

# Move into your repository folder
# %cd /content/drive/MyDrive/WIE3007_Project/

# ===============================
# STEP 7 — Set your Git identity
# ===============================
# !git config --global user.email "your_email@gmail.com"
# !git config --global user.name "your_github_username"

# ===============================
# STEP 8 — Create your branch (RUN ONCE ONLY)
# example: hani-eda, amni-modelling, etc
# ===============================
# !git checkout -b yourname-branch

# %%
# !git branch # see if you in the correct branch
# Out:
# * main

# %% [markdown]
# # SECTION B — DAILY STARTUP (Run this every time you open Colab)

# %%
# ===============================
# DAILY STARTUP (SAFE TO RE-RUN)
# ===============================

from google.colab import drive
drive.mount('/content/drive')

# Enter your repo folder
# %cd /content/drive/MyDrive/WIE3007_Project/WIE3007-DMW-GroupProject

# Switch to your branch (already exists)
# !git checkout yourname-branch

# Pull latest updates from YOUR branch
# !git pull origin yourname-branch

# %% [markdown]
# # SECTION C: WORKSPACE (Do your code here)

# %% [markdown]
# # SECTION D: SAVE WORK (Commit & Push)
# Run this whenever you finish working

# %%
# ===============================
# COMMIT & PUSH
# ===============================

# Add ALL changes
# !git add .

# Make a commit (use meaningful message)
# !git commit -m "Put your commit message here"

# Push to your branch
# !git push origin yourname-branch
# Out:
# [main ed40594] Added Basic Collab and GitHub Setup
#  1 file changed, 1 insertion(+)
#  create mode 100644 DMW_GroupAssignment2.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 3.43 KiB | 219.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To github.com:hanidew/WIE3007-DMW-GroupProject.git
#    ba780a6..ed40594  main -> main

# %% [markdown]
# Other Git Commands:
#
#
# ```
# # To know which branch you are in
# !git branch
#
# # Check status (tengok apa changes yang belum commit)
# !git status
#
# # Switch to main branch
# !git checkout main
#
# # Pull latest main updates
# !git pull origin main
#
# # Merge main into your branch (if needed)
# !git merge main
# ```

# %%
# ===============================
# COMMIT & PUSH
# ===============================

# Add ALL changes
# !git add .

# Make a commit (use meaningful message)
# !git commit -m "Did some minor edits on the "

# Push to your branch
# !git push origin yourname-branch
