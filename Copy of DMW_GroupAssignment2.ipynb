# %% [markdown]
# # 🟦 SECTION A — ONE-TIME SETUP (SAFE TO RUN MULTIPLE TIMES)
#
# (These commands will NOT break anything if re-run)

# %%
# ================================================
# DRIVE + FOLDER SETUP (SAFE TO RE-RUN)
# ================================================

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive
# !mkdir -p WIE3007_Project #Create a folder with this name if doesnt exist
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %% [markdown]
# # 🟦 SECTION B — CLONE REPOSITORY (RUN ONLY ONCE)
#
# ⚠️ Do NOT re-run if repo folder already exists
#
# If you already cloned, SKIP this section.

# %%
# ================================================
# CLONE GITHUB REPO (RUN ONCE ONLY)
# ================================================

# %cd /content/drive/MyDrive/WIE3007_Project

# !git clone https://github.com/hanidew/WIE3007-DMW-GroupProject.git
# Out:
# /content/drive/MyDrive/WIE3007_Project
# fatal: destination path 'WIE3007-DMW-GroupProject' already exists and is not an empty directory.

# %% [markdown]
# # 🟦 SECTION C — ENTER REPO + CHECK STATUS (SAFE TO RE-RUN)
#
# You should see Output: On branch main

# %%
# ================================================
# ENTER REPO
# ================================================

# %cd /content/drive/MyDrive/WIE3007_Project/WIE3007-DMW-GroupProject
# !git status
# Out:
# /content/drive/MyDrive/WIE3007_Project/WIE3007-DMW-GroupProject

# %% [markdown]
# # 🟦 SECTION D — GITHUB IDENTITY (SAFE TO RE-RUN)

# %%
# ================================================
# GIT USER INFO
# ================================================

# !git config --global user.name "hanidew" #"YOUR_GITHUB_USERNAME"
# !git config --global user.email "hanijasmina@gmail.com" #"your_email@gmail.com"

# %% [markdown]
# 🟦 SECTION E — PERSONAL ACCESS TOKEN (PAT) SETUP (RUN ONCE PER USER)
#
# 🔑 Step 1: Create PAT (benda ni buat kat GitHub)

# %% [markdown]
# Go to:
#
# ```
# GitHub → Settings → Developer settings → Personal access tokens → Generate new token (classic)
# ```
#
# Select:
#
# ✅ repo
#
# (expiry: 90 days or no expiry)
#
# Copy the token.

# %% [markdown]
# 🔑 Step 2: Enable credential storage in Colab

# %%
# ================================================
# ENABLE CREDENTIAL STORAGE
# ================================================

# !git config --global credential.helper store

# %% [markdown]
# # 🟦 SECTION F: SAVE WORK — ADD, COMMIT, PUSH (THIS IS WHERE PAT IS USED)
# ⚠️ IMPORTANT:
# Git will ask for:
#
# Username → your GitHub username
#
# Password → paste your PAT (NOT GitHub password)

# %%
# ===============================
# COMMIT & PUSH
# ===============================

# Add ALL changes
# !git add .

# Make a commit (use meaningful message)
# !git commit -m "Put your commit message here"

# ================================================
# PUSH TO GITHUB (PAT REQUIRED)
# ================================================
# Push to your branch
# !git push origin yourname-branch

# %% [markdown]
# Other Git Commands:
#
#
# ```
# # To know which branch you are in
# !git branch
#
# # Nak change to your branch - do this before start working
# git checkout -b yourname-branch
#
# # Check status (tengok apa changes yang belum commit)
# !git status
#
# # Switch to main branch
# !git checkout main
#
# # Pull latest main updates
# !git pull origin main
#
# # Merge main into your branch (if needed)
# !git merge main
# ```

# %% [markdown]
# # 🟦 SECTION E: WORKSPACE (Do your code here)

# %%
# Change to your branch dulu - do this everytime before start working
git checkout -b yourname-branch

# Pull latest main updates
# !git pull origin main

# %%
# ===============================
# COMMIT & PUSH
# ===============================

# See what changes to commit
# !git status

# Add ALL changes
# !git add .
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Make a commit (use meaningful message)
# !git commit -m "Updated setup template"

# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import drive
import os

# 1. Force a sync of the Google Drive metadata
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)

# 2. Go back to your project folder
# %cd /content/drive/MyDrive/WIE3007_Project/WIE3007-DMW-GroupProject

# 3. Check the file modification time to see if Drive actually updated it
# !stat DMW_GroupAssignment2.ipynb
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Mounted at /content/drive
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-767975599.py", line 9, in <cell line: 0>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/WIE3007_Project/WIE3007-DMW-GroupProject')
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "<decorator-gen-85>", line 2, in cd
# ...
